# %%
import pandas as pd
from pypasta import Config
from pypasta.Repository.Mbox import Mbox

# %%
config = Config('linux')
mailbox = Mbox(config)

# Try this also:
# repo.mbox.get_messages(<message_id>)[0].get_payload()

def get_payload(message_id):
    try:
        mailbox.get_messages(message_id)
    except:
        return None

# %%
get_payload('<20190728043619-mutt-send-email-mst@kernel.org>')

# %%
config.__dict__
# Out:
# {'project_name': 'linux',
#  '_project_root': '/home/q503670/PaStA/resources/linux',
#  '_config_file': '/home/q503670/PaStA/resources/linux/config',
#  'd_rout': '/home/q503670/PaStA/resources/linux/Rout',
#  '_mode': <Mode.MBOX: 'mbox'>,
#  'repo_location': '/home/q503670/PaStA/resources/linux/repo/',
#  'repo': <pypasta.Repository.Repository.Repository at 0x7fd5b85d0bb0>,
#  'upstream_range': 'v5.4..v5.5',
#  'f_patch_stack_definition': '/home/q503670/PaStA/resources/linux/resources/patch-stack-definition.dat',
#  'd_stack_hashes': '/home/q503670/PaStA/resources/linux/resources/stack-hashes',
#  'f_upstream_hashes': '/home/q503670/PaStA/resources/linux/resources/stack-hashes/upstream',
#  'upstream_blacklist': 'resources/common/blacklists/linux-blacklist',
#  'd_false_positives': '/home/q503670/PaStA/resources/linux/resources/false-positives',
#  'f_clustering': '/home/q503670/PaStA/resources/linux/resources/patch-groups',
# ...

# %%
patch_responses = pd.read_csv("resources/linux/resources/filtered_responses.csv")
patch_responses.head()
# Out:
#    Unnamed: 0                                           patch_id  \
# 0           0          <000000000000e87d14058e9728d7@google.com>
# 1           1          <000000000000e87d14058e9728d7@google.com>
# 2           2        <20190608051309.4689-1-jontio@i4free.co.nz>
# 3           3       <000101d5abdc$61acff60$2506fe20$@emc.com.tw>
# 4           4  <CAODfWeH67_ZfO7yrrQ+EcFgXd8stA23y6hUtimhzEbXv...
#
#                                   response_author  \
# 0           "Michael S. Tsirkin" <mst@redhat.com>
# 1  Linus Torvalds <torvalds@linux-foundation.org>
# 2                 Johan Hovold <johan@kernel.org>
# 3     Dmitry Torokhov <dmitry.torokhov@gmail.com>
# 4                Jonathan Corbet <corbet@lwn.net>
#
#                                          resp_parent  \
# 0          <000000000000e87d14058e9728d7@google.com>
# 1          <000000000000e87d14058e9728d7@google.com>
# 2        <20190608051309.4689-1-jontio@i4free.co.nz>
# ...
